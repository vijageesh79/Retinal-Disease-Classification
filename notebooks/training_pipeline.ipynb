# %% [markdown]
# # Training Pipeline — Retinal Disease Classification
#
# This notebook runs the full pipeline:
#
# 1. **Data preprocessing** — Load ODIR-5K (or mock data if dataset not present)
# 2. **Model training** — Warm-up (frozen backbone) then fine-tuning
# 3. **Evaluation** — Validation metrics (accuracy, AUC, etc.)
# 4. **Grad-CAM visualization** — Explainability heatmaps saved to `outputs/`
#
# Place the dataset in `dataset/` (see `dataset/README.md`) or the run will use mock data.

# %%
# Run from project root so paths (models/, outputs/, dataset/) resolve correctly
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
os.chdir(project_root)
sys.path.insert(0, project_root)
print(f"Working directory: {os.getcwd()}")

# %%
from main import main

main()
